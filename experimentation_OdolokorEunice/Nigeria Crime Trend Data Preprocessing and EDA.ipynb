# %%
#importing libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\ginan\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ginan\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\ginan\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\ginan\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ginan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ginan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ginan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ginan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ginan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ginan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ginan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ginan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
#loading the data

data = pd.read_csv("Nigeria_1997-2024_Sep20.csv")

# %%
data.head(10)
# Out:
#   event_id_cnty  event_date  year  time_precision           disorder_type  \
# 0      NIG38575  2024-09-20  2024               1          Demonstrations
# 1      NIG38585  2024-09-20  2024               2          Demonstrations
# 2      NIG38581  2024-09-19  2024               1          Demonstrations
# 3      NIG38588  2024-09-19  2024               1  Strategic developments
# 4      NIG38591  2024-09-19  2024               1          Demonstrations
# 5      NIG38626  2024-09-19  2024               1      Political violence
# 6      NIG38579  2024-09-18  2024               1          Demonstrations
# 7      NIG38580  2024-09-18  2024               1          Demonstrations
# 8      NIG38593  2024-09-18  2024               1      Political violence
# 9      NIG38568  2024-09-17  2024               1      Political violence
#
#                event_type         sub_event_type  \
# 0                Protests       Peaceful protest
# 1                Protests       Peaceful protest
# 2                Protests       Peaceful protest
# 3  Strategic developments  Disrupted weapons use
# 4                Protests       Peaceful protest
# 5                 Battles            Armed clash
# 6                Protests       Peaceful protest
# 7                Protests       Peaceful protest
# 8                   Riots           Mob violence
# 9                 Battles            Armed clash
#
#                                actor1                     assoc_actor_1  \
# 0                Protesters (Nigeria)           Refugees/IDPs (Nigeria)
# 1                Protesters (Nigeria)            Muslim Group (Nigeria)
# 2                Protesters (Nigeria)                               NaN
# 3    Police Forces of Nigeria (2023-)                               NaN
# 4                Protesters (Nigeria)    PDP: People's Democratic Party
# 5    Police Forces of Nigeria (2023-)  Kurfi Communal Militia (Nigeria)
# 6                Protesters (Nigeria)                   Women (Nigeria)
# 7                Protesters (Nigeria)                               NaN
# 8                   Rioters (Nigeria)             Labor Group (Nigeria)
# 9  Military Forces of Nigeria (2023-)                               NaN
#
#    inter1  ...  location latitude  longitude  geo_precision  \
# 0       6  ...    Bolori  11.8826    13.0890              1
# 1       6  ...   Ile-Ife   7.4824     4.5603              1
# 2       6  ...     Agodi   7.4035     3.9132              1
# 3       1  ...    Buruku  10.6179     7.2331              1
# 4       6  ...     Wanno   7.1389     6.5724              1
# 5       1  ...     Kurfi  12.6684     7.4841              2
# 6       6  ...    Nsukka   6.8561     7.3927              1
# 7       6  ...     Agodi   7.4035     3.9132              1
# 8       5  ...  Obalende   6.4444     3.3929              1
# 9       1  ...     Alawa  10.3228     6.6542              2
#
#                                               source       source_scale  \
# 0                                           Whatsapp          New media
# 1                              Daily Trust (Nigeria)           National
# 2  Daily Post (Nigeria); Guardian (Nigeria); Saha...  National-Regional
# 3                Daily Post (Nigeria); Nigeria Punch           National
# 4                                 Vanguard (Nigeria)           National
# 5                                            Twitter          New media
# 6                    Sahara Reporters; Sun (Nigeria)  National-Regional
# 7             Daily Post (Nigeria); Sahara Reporters  National-Regional
# 8                                 Vanguard (Nigeria)           National
# 9  Daily Independent (Nigeria); Daily Leadership ...           National
#
#                                                notes fatalities  \
# 0  On 20 September 2024, IDPs (flood victims) fro...          0
# 1  Around 20 September 2024 (as reported), hundre...          0
# 2  On 19 September 2024, for a second consecutive...          0
# 3  Weapons seizure: On 19 September 2024, Police ...          0
# 4  On 19 September 2024, PDP youths protested at ...          0
# 5  On 19 September 2024, police and Kurfi defense...         10
# 6  On 18 September 2024, over 1000 Eha-Alumona wo...          0
# 7  On 18 September 2024, hundreds of residents pr...          0
# 8  On 18 September 2024, commercial drivers attac...          0
# 9  On 17 September 2024, the Nigerian troops clas...          2
#
#                    tags   timestamp
# 0  crowd size=no report  1727134598
# 1   crowd size=hundreds  1727134598
# 2   crowd size=hundreds  1727134598
# 3                   NaN  1727134598
# 4  crowd size=no report  1727134598
# 5                   NaN  1727134598
# 6  crowd size=over 1000  1727134598
# 7   crowd size=hundreds  1727134598
# 8  crowd size=no report  1727134598
# 9                   NaN  1727134598
#
# [10 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['event_id_cnty', 'event_date', 'year', 'time_precision',
#        'disorder_type', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2', 'inter2',
#        'interaction', 'civilian_targeting', 'iso', 'region', 'country',
#        'admin1', 'admin2', 'admin3', 'location', 'latitude', 'longitude',
#        'geo_precision', 'source', 'source_scale', 'notes', 'fatalities',
#        'tags', 'timestamp'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38076 entries, 0 to 38075
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   event_id_cnty       38076 non-null  object
#  1   event_date          38076 non-null  object
#  2   year                38076 non-null  int64
#  3   time_precision      38076 non-null  int64
#  4   disorder_type       38076 non-null  object
#  5   event_type          38076 non-null  object
#  6   sub_event_type      38076 non-null  object
#  7   actor1              38076 non-null  object
#  8   assoc_actor_1       10199 non-null  object
#  9   inter1              38076 non-null  int64
#  10  actor2              29525 non-null  object
#  11  assoc_actor_2       8803 non-null   object
#  12  inter2              38076 non-null  int64
#  13  interaction         38076 non-null  int64
#  14  civilian_targeting  14964 non-null  object
#  15  iso                 38076 non-null  int64
#  16  region              38076 non-null  object
#  17  country             38076 non-null  object
#  18  admin1              38075 non-null  object
#  19  admin2              38075 non-null  object
#  20  admin3              0 non-null      float64
#  21  location            38076 non-null  object
#  22  latitude            38076 non-null  float64
#  23  longitude           38076 non-null  float64
#  24  geo_precision       38076 non-null  int64
#  25  source              38076 non-null  object
#  26  source_scale        38076 non-null  object
#  27  notes               38076 non-null  object
#  28  fatalities          38076 non-null  int64
#  29  tags                7514 non-null   object
#  30  timestamp           38076 non-null  int64
# dtypes: float64(3), int64(9), object(19)
# memory usage: 9.0+ MB

# %%
data.shape
# Out:
# (38076, 31)

# %%
#checking for missing values in every column
data.isna().sum()
# Out:
# event_id_cnty             0
# event_date                0
# year                      0
# time_precision            0
# disorder_type             0
# event_type                0
# sub_event_type            0
# actor1                    0
# assoc_actor_1         27877
# inter1                    0
# actor2                 8551
# assoc_actor_2         29273
# inter2                    0
# interaction               0
# civilian_targeting    23112
# iso                       0
# region                    0
# country                   0
# admin1                    1
# admin2                    1
# admin3                38076
# location                  0
# latitude                  0
# longitude                 0
# geo_precision             0
# source                    0
# source_scale              0
# notes                     0
# fatalities                0
# tags                  30562
# timestamp                 0
# dtype: int64

# %%
data.describe()
# Out:
#                year  time_precision        inter1        inter2   interaction  \
# count  38076.000000    38076.000000  38076.000000  38076.000000  38076.000000
# mean    2018.643502        1.109439      3.566210      3.779914     36.497085
# std        5.312043        0.325537      1.717226      2.963821     17.550438
# min     1997.000000        1.000000      1.000000      0.000000     10.000000
# 25%     2016.000000        1.000000      2.000000      1.000000     16.000000
# 50%     2020.000000        1.000000      3.000000      4.000000     37.000000
# 75%     2022.000000        1.000000      5.000000      7.000000     50.000000
# max     2024.000000        3.000000      8.000000      8.000000     88.000000
#
#                 iso  admin3      latitude     longitude  geo_precision  \
# count  38076.000000     0.0  38076.000000  38076.000000   38076.000000
# mean     565.990493     NaN      8.760764      7.907555       1.369078
# std        1.855167     NaN      2.611340      2.956555       0.516271
# min      204.000000     NaN      2.855900      1.328200       1.000000
# 25%      566.000000     NaN      6.453100      6.078900       1.000000
# 50%      566.000000     NaN      8.700000      7.352600       1.000000
# 75%      566.000000     NaN     11.200200      8.900000       2.000000
# max      566.000000     NaN     13.832400     14.650000       3.000000
#
#          fatalities     timestamp
# count  38076.000000  3.807600e+04
# mean       3.151723  1.677538e+09
# std       14.875568  5.034708e+07
# min        0.000000  1.552576e+09
# 25%        0.000000  1.653503e+09
# 50%        0.000000  1.702343e+09
# 75%        2.000000  1.713223e+09
# max     1000.000000  1.727135e+09

# %%
#dropping irrelevant columns with missing values
data = data.drop(['tags', 'admin3','civilian_targeting','assoc_actor_2','assoc_actor_1','actor2'], axis=1)

# %%
#droping rows with missing values
data_cleaned = data.dropna()

# %%
#make a copy of the dataframe
data_cleaned = data_cleaned.copy()
# convert 'event date' column to datetime format
data_cleaned ['event_date'] = pd.to_datetime(data_cleaned ['event_date'], errors='coerce')

# Extract month and day into new columns
data_cleaned ['Month'] = data_cleaned ['event_date'].dt.month
data_cleaned ['Day'] = data_cleaned ['event_date'].dt.day

# %%
#checking for duplicates
data_cleaned.duplicated().sum()
# Out:
# 0

# %%
data_cleaned.shape
# Out:
# (38075, 27)

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38075 entries, 0 to 38075
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_id_cnty   38075 non-null  object
#  1   event_date      38075 non-null  datetime64[ns]
#  2   year            38075 non-null  int64
#  3   time_precision  38075 non-null  int64
#  4   disorder_type   38075 non-null  object
#  5   event_type      38075 non-null  object
#  6   sub_event_type  38075 non-null  object
#  7   actor1          38075 non-null  object
#  8   inter1          38075 non-null  int64
#  9   inter2          38075 non-null  int64
#  10  interaction     38075 non-null  int64
#  11  iso             38075 non-null  int64
#  12  region          38075 non-null  object
#  13  country         38075 non-null  object
#  14  admin1          38075 non-null  object
#  15  admin2          38075 non-null  object
#  16  location        38075 non-null  object
#  17  latitude        38075 non-null  float64
#  18  longitude       38075 non-null  float64
#  19  geo_precision   38075 non-null  int64
#  20  source          38075 non-null  object
#  21  source_scale    38075 non-null  object
#  22  notes           38075 non-null  object
#  23  fatalities      38075 non-null  int64
#  24  timestamp       38075 non-null  int64
#  25  Month           38075 non-null  int32
#  26  Day             38075 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(9), object(13)
# memory usage: 7.8+ MB

# %%
data_cleaned.head()
# Out:
#   event_id_cnty event_date  year  time_precision           disorder_type  \
# 0      NIG38575 2024-09-20  2024               1          Demonstrations
# 1      NIG38585 2024-09-20  2024               2          Demonstrations
# 2      NIG38581 2024-09-19  2024               1          Demonstrations
# 3      NIG38588 2024-09-19  2024               1  Strategic developments
# 4      NIG38591 2024-09-19  2024               1          Demonstrations
#
#                event_type         sub_event_type  \
# 0                Protests       Peaceful protest
# 1                Protests       Peaceful protest
# 2                Protests       Peaceful protest
# 3  Strategic developments  Disrupted weapons use
# 4                Protests       Peaceful protest
#
#                              actor1  inter1  inter2  ...  latitude  longitude  \
# 0              Protesters (Nigeria)       6       0  ...   11.8826    13.0890
# 1              Protesters (Nigeria)       6       0  ...    7.4824     4.5603
# 2              Protesters (Nigeria)       6       0  ...    7.4035     3.9132
# 3  Police Forces of Nigeria (2023-)       1       4  ...   10.6179     7.2331
# 4              Protesters (Nigeria)       6       0  ...    7.1389     6.5724
#
#   geo_precision                                             source  \
# 0             1                                           Whatsapp
# 1             1                              Daily Trust (Nigeria)
# 2             1  Daily Post (Nigeria); Guardian (Nigeria); Saha...
# 3             1                Daily Post (Nigeria); Nigeria Punch
# 4             1                                 Vanguard (Nigeria)
#
#         source_scale                                              notes  \
# 0          New media  On 20 September 2024, IDPs (flood victims) fro...
# 1           National  Around 20 September 2024 (as reported), hundre...
# 2  National-Regional  On 19 September 2024, for a second consecutive...
# 3           National  Weapons seizure: On 19 September 2024, Police ...
# 4           National  On 19 September 2024, PDP youths protested at ...
#
#   fatalities   timestamp  Month  Day
# 0          0  1727134598      9   20
# 1          0  1727134598      9   20
# 2          0  1727134598      9   19
# 3          0  1727134598      9   19
# 4          0  1727134598      9   19
#
# [5 rows x 27 columns]

# %%
data_cleaned.to_csv('cleaned_data_crime_rate.csv', index=False)

# %% [markdown]
#  <span style="font-size:20px">Exploratory Data Analysis</span>

# %%
# Where do Most Crime Occur?

plt.figure(figsize=(14, 7))
sns.countplot(
    x=data_cleaned['location'], 
    order=data_cleaned['location'].value_counts().iloc[:15].index, 
    palette="viridis"
)
plt.xticks(rotation=60) 
plt.xlabel("Location")
plt.ylabel("Count")
plt.title("Top 15 Locations by Crime Count")
plt.show()

# %%
# What event leads to most crime?

# Setting up the figure size
plt.figure(figsize=(10, 6))

# Plotting the counts of each event type
sns.countplot(
    x=data_cleaned['event_type'], 
    data=data_cleaned, 
    order=data_cleaned['event_type'].value_counts().index, 
    palette="magma"
)

# Adding labels and title
plt.xlabel("Event Type")
plt.ylabel("Count")
plt.title("Most Common Crime Causing Event")
plt.xticks(rotation=60)  # Rotate x-axis labels if they are long
plt.show()

# %%
#What Event is the Deadliest?

# Group by 'Event Type' and sum the fatalities
fatalities_by_event = data_cleaned.groupby('event_type')['fatalities'].sum().reset_index()

# Sort by the number of fatalities in descending order
fatalities_by_event = fatalities_by_event.sort_values(by='fatalities', ascending=False)

# Setting up the figure size
plt.figure(figsize=(10, 6))

# Plotting the summed fatalities for each event type
sns.barplot(
    x=data_cleaned['event_type'], 
    y=data_cleaned['fatalities'], 
    data=fatalities_by_event, 
    palette="coolwarm"
)

# Adding labels and title
plt.xlabel("Event Type")
plt.ylabel("Total Fatalities")
plt.title("Total Fatalities by Event Type")
plt.xticks(rotation=60) 
plt.show()

# %%
#Number of Crimes per Month

# Count occurrences of each month
month_counts = data_cleaned['Month'].value_counts().reindex(range(1, 13), fill_value=0)  

# Plotting
plt.figure(figsize=(14, 7))

# Bar plot
sns.barplot(x=month_counts.index, y=month_counts.values, color='navy', label='Bar Chart')

# Line plot
plt.plot(month_counts.index - 1, month_counts.values, color='red', marker='o', linestyle='-', label='Line Chart')

# Set x-ticks to correspond with month names
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(ticks=month_counts.index - 1, labels=month_names, rotation=45)

# Adjust layout to avoid label clipping
plt.tight_layout()

# Add title and legend
plt.title("Number of Crimes per Month")
plt.xlabel("Month")
plt.ylabel("Number of Crimes")
plt.legend()

# Display the plot
plt.show()

# %%
#Number of Crimes per Day

# Count occurrences of each day
day_counts = data_cleaned['Day'].value_counts().reindex(range(1, 8), fill_value=0)  

# Plotting
plt.figure(figsize=(10, 6))

# Bar plot

sns.barplot(x=day_counts.index, y=day_counts.values, color='navy')

# Line plot
plt.plot(day_counts.index - 1, day_counts.values, color='red', marker='o', linestyle='-', label='Line Chart')

# Set x-ticks to correspond with month names
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 
               'Sunday']
plt.xticks(ticks=day_counts.index - 1, labels=day_names, rotation=45)  #

# Adjust layout to avoid label clipping
plt.tight_layout()
plt.title("Number of Crimes per Day")
plt.show()

# %%
#Crime Rate per Year

# Group by year and count occurrences
yearly_crime_rate = data_cleaned['year'].value_counts().sort_index()

# Create a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x=yearly_crime_rate.index, y=yearly_crime_rate.values, marker='o')

# Add gridlines
plt.grid(color='black', linestyle='--', linewidth=0.5, alpha=0.7)  # Black gridlines only

# Title and labels
plt.title('Yearly Crime Rate')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.xticks(yearly_crime_rate.index,rotation=60)  # Show all years on the x-axis
plt.show()

# %%
#Whose Actions Led to A lot of Fatalities?

# Step 1: Aggregate fatalities by actor
actor_fatalities = data_cleaned.groupby('actor1')['fatalities'].sum().reset_index()

# Step 2: Create a dictionary for the word cloud
word_freq = dict(zip(actor_fatalities['actor1'], actor_fatalities['fatalities']))

# Step 3: Generate the word cloud
wordcloud = WordCloud(
    background_color='black',
    width=800,
    height=400
).generate_from_frequencies(word_freq)

# Step 4: Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axes
plt.title("Whose Actions led to the Most Fatalities", fontsize=20, color='black')
plt.show()
